# %% [markdown]
# # Mid Term 1 - KNN & Logistic Regression
# *Authors*:  Aliotta Lorenzo, Prataiolo Loris

# %%
import numpy as np

# %%
def load_dataset(ds_filepath):
    with np.load(ds_filepath) as ds:
        return ds, ds.file

# %% [markdown]
# # KNN

# %% [markdown]
# # Logistic Regression
